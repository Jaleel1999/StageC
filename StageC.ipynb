# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
import numpy as np

# %%
df = pd.read_csv("Data_for_UCI_named.csv")

# %%
df
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
# ...

# %%
df.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable

# %%
features = df.drop(columns=["stab","stabf"])

# %%
features
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4
# ...

# %%
target = df["stabf"]

# %%
target
# Out:
# 0       unstable
# 1         stable
# 2       unstable
# 3       unstable
# 4       unstable
#           ...
# 9995    unstable
# 9996      stable
# 9997      stable
# 9998    unstable
# 9999    unstable
# Name: stabf, Length: 10000, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
target = le.fit_transform(target)

# %%
target
# Out:
# array([1, 0, 1, ..., 0, 1, 1])

# %%
#Splitting the dataset into a trainingset and testset.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(features,target,test_size=0.2, random_state=1)

# %%
X_train
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 2694  6.255995  2.542401  7.024714  9.476518  3.529888 -1.224881 -0.688228
# 5140  5.070581  5.490253  8.075688  0.761075  4.220888 -1.280596 -1.902185
# 2568  1.220072  8.804028  3.874283  8.433949  3.614027 -1.039236 -0.953566
# 3671  7.498402  6.697603  8.798626  2.126236  3.134585 -1.581906 -0.589386
# 7427  7.074006  1.337511  6.100756  7.759156  2.526922 -0.922540 -0.632600
# ...        ...       ...       ...       ...       ...       ...       ...
# 2895  9.504984  5.265415  2.029617  8.026334  3.449756 -0.922754 -1.526305
# 7813  8.035818  4.632548  1.177810  1.204950  4.093208 -1.568218 -0.819966
# 905   7.052560  3.264057  1.405949  4.497549  3.741358 -0.629026 -1.407945
# 5192  5.085242  1.790031  2.486392  2.848192  3.159670 -0.892898 -1.025461
# 235   1.205354  6.995045  5.930860  2.523856  5.230127 -1.755047 -1.567927
#
#             p4        g1        g2        g3        g4
# ...

# %%
#implementing XGBOOSTClassifier.
xgb = XGBClassifier()

# %%
xgb.fit(X_train,y_train)
# Out:
# [21:18:54] INFO: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-030221e36e1a46bfb-1/xgboost/xgboost-ci-windows/src/tree/updater_prune.cc:98: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [21:18:54] INFO: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-030221e36e1a46bfb-1/xgboost/xgboost-ci-windows/src/tree/updater_prune.cc:98: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [21:18:54] INFO: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-030221e36e1a46bfb-1/xgboost/xgboost-ci-windows/src/tree/updater_prune.cc:98: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [21:18:54] INFO: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-030221e36e1a46bfb-1/xgboost/xgboost-ci-windows/src/tree/updater_prune.cc:98: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# ...

# %%
from sklearn.metrics import recall_score,accuracy_score,precision_score,f1_score,confusion_matrix

# %%
ypred = xgb.predict(X_test)

# %%
accuracy = accuracy_score(y_true=y_test,y_pred=ypred)

# %%
#Accuracy for XGB model.
accuracy
# Out:
# 0.9455

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)

# Predicting a new result
ypred1 = classifier.predict(X_test)

# %%
ypred1
# Out:
# array([1, 1, 0, ..., 0, 0, 1])

# %%
accuracy1 = accuracy_score(y_true=y_test,y_pred=ypred1)

# %%
#Accuracy for RandomForest Classifier.
accuracy1
# Out:
# 0.924

# %%
import lightgbm as lgb
clf = lgb.LGBMClassifier()
clf.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
ypred2 = clf.predict(X_test)

# %%
accuracy2 = accuracy_score(y_true=y_test,y_pred=ypred2)

# %%
#Accuracy LGBM classifier.
accuracy2
# Out:
# 0.939

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
#Hyperparameter 1 caclulation.
clf2 = ExtraTreesClassifier(n_estimators = 300 , min_samples_split = 5 , min_samples_leaf = 6, max_features = 'auto')
clf2.fit(X_train, y_train)
ypred3 = clf2.predict(X_test)

# %%
accuracy3 = accuracy_score(y_true=y_test,y_pred=ypred3)

# %%
accuracy3
# Out:
# 0.9155

# %%
# define search space
space = dict()

# define search
search = RandomizedSearchCV(clf2,space,cv=5, n_iter=10, scoring = 'accuracy', n_jobs = -1, verbose = 1,random_state=1)

# %%
search.fit(X_train,y_train)
# Out:
# C:\Users\jalee\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# RandomizedSearchCV(cv=5,
#                    estimator=ExtraTreesClassifier(min_samples_leaf=6,
#                                                   min_samples_split=5,
#                                                   n_estimators=300),
#                    n_jobs=-1, param_distributions={}, random_state=1,
#                    scoring='accuracy', verbose=1)

# %%
ysc = search.predict(X_test)

# %%
accuracy4 = accuracy_score(y_true=y_test,y_pred=ysc)

# %%
accuracy4
# Out:
# 0.916
